# %%
from __future__ import absolute_import, division, print_function

import os
#import urllib, cStringIO

import pymongo as pm

import numpy as np
import scipy.stats as stats
import pandas as pd
import json
import re

from PIL import Image
import base64
import sys

import matplotlib
from matplotlib import pylab, mlab, pyplot
# %matplotlib inline
from IPython.core.pylabtools import figsize, getfigs
plt = pyplot
import seaborn as sns
sns.set_context('talk')
sns.set_style('white')

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")

# %%
# directory & file hierarchy
proj_dir = os.path.abspath('../../..')
analysis_dir = os.getcwd()
results_dir = os.path.join(proj_dir,'results')
plot_dir = os.path.join(results_dir,'plots')
csv_dir = os.path.join(results_dir,'csv')
exp_dir = os.path.abspath(os.path.join(proj_dir,'experiments'))
sketch_dir = os.path.abspath(os.path.join(proj_dir,'sketches'))

## add helpers to python path
if os.path.join(proj_dir,'analysis','python') not in sys.path:
    sys.path.append(os.path.join(proj_dir,'analysis','python'))
    
if not os.path.exists(results_dir):
    os.makedirs(results_dir)
    
if not os.path.exists(plot_dir):
    os.makedirs(plot_dir)   
    
if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)       
    
# Assign variables within imported analysis helpers
import analysis_helpers as h
if sys.version_info[0]>=3:
    from importlib import reload
reload(h)
# Out:
# <module 'analysis_helpers' from '/home/megsano/graphical_conventions/analysis/python/analysis_helpers.pyc'>

# %% [markdown]
# ### load dataframe

# %%
D = pd.read_csv(os.path.join(results_dir,'graphical_conventions.csv'))

# %%
### add session ids for recog experiment (delete later)

# %%
# create tuple for each gameID, target pair 
D_repeated = D[D['condition'] == 'repeated']
repeated_tuple_list = []
for g in D_repeated['gameID'].unique():
    target_list = D_repeated[D_repeated['gameID'] == g]['target'].unique()
    for t in target_list:
        repeated_tuple_list.append((g, t))
repeated = np.array(repeated_tuple_list)
assert len(repeated) == 268 
        
# create tuple for each gameID, target pair 
D_control = D[D['condition'] == 'control']
control_tuple_list = []
for g in D_control['gameID'].unique():
    target_list = D_control[D_control['gameID'] == g]['target'].unique()
    for t in target_list:
        control_tuple_list.append((g, t))
control = np.array(control_tuple_list)
assert len(control) == 268 

# create new dataframe with gameID, tuple pairs 
new_d = pd.DataFrame()
for rep in range(8):
    new_d['repeated_rep_{}'.format(rep)] = list(np.roll(repeated, rep * 4, axis=0))
for rep in [0,7]:
    new_d['control_rep_{}'.format(rep)] = list(np.roll(control, (rep+8) * 4, axis=0))
    
# add recog sesion ids to main dataframe 
D['recog_id'] = [0] * len(D)
for i,d in new_d.iterrows():
    for j, pair in enumerate(list(d)):
        if j == 8 or j == 9:
            condition = 'control' 
            rep_num = 0 if j == 8 else 1
        else:
            condition = 'repeated'
            rep_num = j
        row_index = list(D.index[(D['gameID'] == pair[0]) & (D['target'] == pair[1]) & (D['repetition'] == rep_num) & (D['condition'] == condition)])[0]
        D.loc[row_index, 'recog_id'] = i

# %%
## to do 
# add target shapenet ids 
target_shapenets = [0] * len(D)
D['target_shapenet'] = target_shapenets
for i,d in D.iterrows():
    target = d['target']
    shapenet_id = h.object_to_shapenet[target]
    D.loc[i, 'target_shapenet'] = shapenet_id
# Out:
# ['waiting_07' 'waiting_04' 'waiting_00' 'waiting_01']

# %%
# add distractor 
# add shapenet ids for distractors
distractors = [[0]] * len(D)
distractors_shapenets = [[0]] * len(D)
D['distractors'] = distractors 
D['distractors_shapenet'] = distractors_shapenets
for i,d in D.iterrows():
    gameID = d['gameID']
    condition = d['condition']
    target_list = D[(D['gameID'] == gameID) & (D['condition'] == condition)]['target'].unique()
    distractors_list = [target for target in target_list if target !=  d['target']]
    distractors_dict = {'distractor1':distractors_list[0],'distractor2':distractors_list[1],'distractor3':distractors_list[2]}
    D.at[i, 'distractors'] = distractors_dict
    shapenets_list = [h.object_to_shapenet[dist] for dist in distractors_list]
    shapenets_dict = {'distractor1':shapenets_list[0],'distractor2':shapenets_list[1],'distractor3':shapenets_list[2]}
    D.at[i, 'distractors_shapenet'] = shapenets_dict

# %%
D
# Out:
#       row_index                                     gameID  trialNum  \
# 0             0  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         1
# 1             1  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         2
# 2             2  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         3
# 3             3  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         4
# 4             4  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         5
# 5             5  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         6
# 6             6  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         7
# 7             7  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         8
# 8             8  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         9
# 9             9  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        10
# 10           10  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        11
# 11           11  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        12
# 12           12  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        13
# 13           13  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        14
# 14           14  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        15
# 15           15  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        16
# 16           16  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        17
# 17           17  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        18
# 18           18  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        19
# 19           19  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        20
# 20           20  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        21
# 21           21  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        22
# 22           22  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        23
# 23           23  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        24
# 24           24  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        25
# 25           25  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        26
# 26           26  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        27
# 27           27  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        28
# 28           28  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        29
# 29           29  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb        30
# ...         ...                                        ...       ...
# 2650       1330  6725-7351d615-c816-4608-8554-afecf47c4b42        11
# 2651       1331  6725-7351d615-c816-4608-8554-afecf47c4b42        12
# 2652       1332  6725-7351d615-c816-4608-8554-afecf47c4b42        13
# 2653       1333  6725-7351d615-c816-4608-8554-afecf47c4b42        14
# 2654       1334  6725-7351d615-c816-4608-8554-afecf47c4b42        15
# 2655       1335  6725-7351d615-c816-4608-8554-afecf47c4b42        16
# 2656       1336  6725-7351d615-c816-4608-8554-afecf47c4b42        17
# 2657       1337  6725-7351d615-c816-4608-8554-afecf47c4b42        18
# 2658       1338  6725-7351d615-c816-4608-8554-afecf47c4b42        19
# 2659       1339  6725-7351d615-c816-4608-8554-afecf47c4b42        20
# 2660       1340  6725-7351d615-c816-4608-8554-afecf47c4b42        21
# 2661       1341  6725-7351d615-c816-4608-8554-afecf47c4b42        22
# 2662       1342  6725-7351d615-c816-4608-8554-afecf47c4b42        23
# 2663       1343  6725-7351d615-c816-4608-8554-afecf47c4b42        24
# 2664       1344  6725-7351d615-c816-4608-8554-afecf47c4b42        25
# 2665       1345  6725-7351d615-c816-4608-8554-afecf47c4b42        26
# 2666       1346  6725-7351d615-c816-4608-8554-afecf47c4b42        27
# 2667       1347  6725-7351d615-c816-4608-8554-afecf47c4b42        28
# 2668       1348  6725-7351d615-c816-4608-8554-afecf47c4b42        29
# 2669       1349  6725-7351d615-c816-4608-8554-afecf47c4b42        30
# 2670       1350  6725-7351d615-c816-4608-8554-afecf47c4b42        31
# 2671       1351  6725-7351d615-c816-4608-8554-afecf47c4b42        32
# 2672       1352  6725-7351d615-c816-4608-8554-afecf47c4b42        33
# 2673       1353  6725-7351d615-c816-4608-8554-afecf47c4b42        34
# 2674       1354  6725-7351d615-c816-4608-8554-afecf47c4b42        35
# 2675       1355  6725-7351d615-c816-4608-8554-afecf47c4b42        36
# 2676       1356  6725-7351d615-c816-4608-8554-afecf47c4b42        37
# 2677       1357  6725-7351d615-c816-4608-8554-afecf47c4b42        38
# 2678       1358  6725-7351d615-c816-4608-8554-afecf47c4b42        39
# 2679       1359  6725-7351d615-c816-4608-8554-afecf47c4b42        40
#
#      condition      target category  repetition     phase Generalization  \
# 0     repeated  waiting_07  waiting           0       pre         within
# 1      control  waiting_02  waiting           0       pre         within
# 2      control  waiting_06  waiting           0       pre         within
# 3     repeated  waiting_04  waiting           0       pre         within
# 4     repeated  waiting_00  waiting           0       pre         within
# 5     repeated  waiting_01  waiting           0       pre         within
# 6      control  waiting_03  waiting           0       pre         within
# 7      control  waiting_05  waiting           0       pre         within
# 8     repeated  waiting_00  waiting           1  repeated         within
# 9     repeated  waiting_07  waiting           1  repeated         within
# 10    repeated  waiting_04  waiting           1  repeated         within
# 11    repeated  waiting_01  waiting           1  repeated         within
# 12    repeated  waiting_00  waiting           2  repeated         within
# 13    repeated  waiting_07  waiting           2  repeated         within
# 14    repeated  waiting_04  waiting           2  repeated         within
# 15    repeated  waiting_01  waiting           2  repeated         within
# 16    repeated  waiting_07  waiting           3  repeated         within
# 17    repeated  waiting_00  waiting           3  repeated         within
# 18    repeated  waiting_01  waiting           3  repeated         within
# 19    repeated  waiting_04  waiting           3  repeated         within
# 20    repeated  waiting_00  waiting           4  repeated         within
# 21    repeated  waiting_01  waiting           4  repeated         within
# 22    repeated  waiting_07  waiting           4  repeated         within
# 23    repeated  waiting_04  waiting           4  repeated         within
# 24    repeated  waiting_00  waiting           5  repeated         within
# 25    repeated  waiting_07  waiting           5  repeated         within
# 26    repeated  waiting_01  waiting           5  repeated         within
# 27    repeated  waiting_04  waiting           5  repeated         within
# 28    repeated  waiting_00  waiting           6  repeated         within
# 29    repeated  waiting_01  waiting           6  repeated         within
# ...        ...         ...      ...         ...       ...            ...
# 2650  repeated   dining_03   dining           1  repeated        between
# 2651  repeated   dining_06   dining           1  repeated        between
# 2652  repeated   dining_06   dining           2  repeated        between
# 2653  repeated   dining_07   dining           2  repeated        between
# 2654  repeated   dining_03   dining           2  repeated        between
# 2655  repeated   dining_04   dining           2  repeated        between
# 2656  repeated   dining_07   dining           3  repeated        between
# 2657  repeated   dining_04   dining           3  repeated        between
# 2658  repeated   dining_03   dining           3  repeated        between
# 2659  repeated   dining_06   dining           3  repeated        between
# 2660  repeated   dining_04   dining           4  repeated        between
# 2661  repeated   dining_06   dining           4  repeated        between
# 2662  repeated   dining_07   dining           4  repeated        between
# 2663  repeated   dining_03   dining           4  repeated        between
# 2664  repeated   dining_04   dining           5  repeated        between
# 2665  repeated   dining_03   dining           5  repeated        between
# 2666  repeated   dining_06   dining           5  repeated        between
# 2667  repeated   dining_07   dining           5  repeated        between
# 2668  repeated   dining_03   dining           6  repeated        between
# 2669  repeated   dining_06   dining           6  repeated        between
# 2670  repeated   dining_04   dining           6  repeated        between
# 2671  repeated   dining_07   dining           6  repeated        between
# 2672   control  waiting_00  waiting           1      post        between
# 2673   control  waiting_02  waiting           1      post        between
# 2674  repeated   dining_04   dining           7      post        between
# 2675  repeated   dining_03   dining           7      post        between
# 2676  repeated   dining_06   dining           7      post        between
# 2677   control  waiting_05  waiting           1      post        between
# 2678  repeated   dining_07   dining           7      post        between
# 2679   control  waiting_01  waiting           1      post        between
#
#       drawDuration                        ...                          \
# 0            5.415                        ...
# 1           12.327                        ...
# 2            9.014                        ...
# 3            9.451                        ...
# 4            8.538                        ...
# 5            8.660                        ...
# 6            3.443                        ...
# 7            9.140                        ...
# 8            8.248                        ...
# 9            3.628                        ...
# 10           5.250                        ...
# 11           7.640                        ...
# 12          12.479                        ...
# 13           3.254                        ...
# 14           5.044                        ...
# 15           5.395                        ...
# 16           3.847                        ...
# 17           9.996                        ...
# 18           3.204                        ...
# 19           5.634                        ...
# 20           6.085                        ...
# 21           6.005                        ...
# 22           2.156                        ...
# 23           3.574                        ...
# 24           5.736                        ...
# 25           1.615                        ...
# 26           4.424                        ...
# 27           1.454                        ...
# 28           2.987                        ...
# 29           4.487                        ...
# ...            ...                        ...
# 2650         5.160                        ...
# 2651         6.819                        ...
# 2652         9.723                        ...
# 2653        17.487                        ...
# 2654         4.605                        ...
# 2655         9.821                        ...
# 2656         7.686                        ...
# 2657         6.803                        ...
# 2658         4.247                        ...
# 2659         4.599                        ...
# 2660         8.202                        ...
# 2661         6.307                        ...
# 2662         6.667                        ...
# 2663         7.352                        ...
# 2664         8.670                        ...
# 2665         5.655                        ...
# 2666         4.667                        ...
# 2667         7.017                        ...
# 2668         4.097                        ...
# 2669        12.140                        ...
# 2670         9.753                        ...
# 2671         4.888                        ...
# 2672         6.844                        ...
# 2673         3.690                        ...
# 2674         6.473                        ...
# 2675         4.502                        ...
# 2676         4.645                        ...
# 2677         4.668                        ...
# 2678         6.902                        ...
# 2679         4.935                        ...
#
#       numCurvesPerSketch numCurvesPerStroke  timedOut  \
# 0                      7           2.333333     False
# 1                     14           2.000000     False
# 2                     10           2.000000     False
# 3                     17           4.250000     False
# 4                     11           3.666667     False
# 5                     13           3.250000     False
# 6                      5           5.000000     False
# 7                     13           6.500000     False
# 8                     12           6.000000     False
# 9                      7           3.500000     False
# 10                    10           2.500000     False
# 11                    11           3.666667     False
# 12                    18           9.000000     False
# 13                     4           2.000000     False
# 14                    10           3.333333     False
# 15                    12           6.000000     False
# 16                     6           3.000000     False
# 17                    23          11.500000     False
# 18                     8           8.000000     False
# 19                    13           3.250000     False
# 20                     9           4.500000     False
# 21                    10           5.000000     False
# 22                     4           4.000000     False
# 23                     5           1.666667     False
# 2652  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2653  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2654  {u'distractors1': u'38f87e02e850d3bd1d5ccc40b5...
# 2655  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2656  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2657  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2658  {u'distractors1': u'38f87e02e850d3bd1d5ccc40b5...
# 2659  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2660  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2661  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2662  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2663  {u'distractors1': u'38f87e02e850d3bd1d5ccc40b5...
# 2664  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2665  {u'distractors1': u'38f87e02e850d3bd1d5ccc40b5...
# 2666  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2667  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2668  {u'distractors1': u'38f87e02e850d3bd1d5ccc40b5...
# 2669  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2670  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2671  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2672  {u'distractors1': u'1da9942b2ab7082b2ba1fdc12e...
# 2673  {u'distractors1': u'1da9942b2ab7082b2ba1fdc12e...
# 2674  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2675  {u'distractors1': u'38f87e02e850d3bd1d5ccc40b5...
# 2676  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2677  {u'distractors1': u'1da9942b2ab7082b2ba1fdc12e...
# 2678  {u'distractors1': u'3466b6ecd040e252c215f685ba...
# 2679  {u'distractors1': u'1d1641362ad5a34ac3bd24f986...
#
# [2680 rows x 24 columns]

# %%
D.to_csv(os.path.join(results_dir, 'graphical_conventions.csv'))
check = pd.read_csv(os.path.join(results_dir, 'graphical_conventions.csv'))
check
# Out:
#       Unnamed: 0  row_index                                     gameID  \
# 0              0          0  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 1              1          1  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 2              2          2  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 3              3          3  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 4              4          4  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 5              5          5  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 6              6          6  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 7              7          7  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 8              8          8  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 9              9          9  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 10            10         10  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 11            11         11  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 12            12         12  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 13            13         13  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 14            14         14  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 15            15         15  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 16            16         16  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 17            17         17  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 18            18         18  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 19            19         19  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 20            20         20  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 21            21         21  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 22            22         22  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 23            23         23  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 24            24         24  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 25            25         25  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 26            26         26  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 27            27         27  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 28            28         28  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# 29            29         29  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# ...          ...        ...                                        ...
# 2650        2650       1330  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2651        2651       1331  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2652        2652       1332  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2653        2653       1333  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2654        2654       1334  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2655        2655       1335  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2656        2656       1336  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2657        2657       1337  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2658        2658       1338  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2659        2659       1339  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2660        2660       1340  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2661        2661       1341  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2662        2662       1342  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2663        2663       1343  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2664        2664       1344  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2665        2665       1345  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2666        2666       1346  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2667        2667       1347  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2668        2668       1348  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2669        2669       1349  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2670        2670       1350  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2671        2671       1351  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2672        2672       1352  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2673        2673       1353  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2674        2674       1354  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2675        2675       1355  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2676        2676       1356  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2677        2677       1357  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2678        2678       1358  6725-7351d615-c816-4608-8554-afecf47c4b42
# 2679        2679       1359  6725-7351d615-c816-4608-8554-afecf47c4b42
#
#       trialNum condition      target category  repetition     phase  \
# 0            1  repeated  waiting_07  waiting           0       pre
# 1            2   control  waiting_02  waiting           0       pre
# 2            3   control  waiting_06  waiting           0       pre
# 3            4  repeated  waiting_04  waiting           0       pre
# 4            5  repeated  waiting_00  waiting           0       pre
# 5            6  repeated  waiting_01  waiting           0       pre
# 6            7   control  waiting_03  waiting           0       pre
# 7            8   control  waiting_05  waiting           0       pre
# 8            9  repeated  waiting_00  waiting           1  repeated
# 9           10  repeated  waiting_07  waiting           1  repeated
# 10          11  repeated  waiting_04  waiting           1  repeated
# 11          12  repeated  waiting_01  waiting           1  repeated
# 12          13  repeated  waiting_00  waiting           2  repeated
# 13          14  repeated  waiting_07  waiting           2  repeated
# 14          15  repeated  waiting_04  waiting           2  repeated
# 15          16  repeated  waiting_01  waiting           2  repeated
# 16          17  repeated  waiting_07  waiting           3  repeated
# 17          18  repeated  waiting_00  waiting           3  repeated
# 18          19  repeated  waiting_01  waiting           3  repeated
# 19          20  repeated  waiting_04  waiting           3  repeated
# 20          21  repeated  waiting_00  waiting           4  repeated
# 21          22  repeated  waiting_01  waiting           4  repeated
# 22          23  repeated  waiting_07  waiting           4  repeated
# 23          24  repeated  waiting_04  waiting           4  repeated
# 24          25  repeated  waiting_00  waiting           5  repeated
# 25          26  repeated  waiting_07  waiting           5  repeated
# 26          27  repeated  waiting_01  waiting           5  repeated
# 27          28  repeated  waiting_04  waiting           5  repeated
# 28          29  repeated  waiting_00  waiting           6  repeated
# 29          30  repeated  waiting_01  waiting           6  repeated
# ...        ...       ...         ...      ...         ...       ...
# 2650        11  repeated   dining_03   dining           1  repeated
# 2651        12  repeated   dining_06   dining           1  repeated
# 2652        13  repeated   dining_06   dining           2  repeated
# 2653        14  repeated   dining_07   dining           2  repeated
# 2654        15  repeated   dining_03   dining           2  repeated
# 2655        16  repeated   dining_04   dining           2  repeated
# 2656        17  repeated   dining_07   dining           3  repeated
# 2657        18  repeated   dining_04   dining           3  repeated
# 2658        19  repeated   dining_03   dining           3  repeated
# 2659        20  repeated   dining_06   dining           3  repeated
# 2660        21  repeated   dining_04   dining           4  repeated
# 2661        22  repeated   dining_06   dining           4  repeated
# 2662        23  repeated   dining_07   dining           4  repeated
# 2663        24  repeated   dining_03   dining           4  repeated
# 2664        25  repeated   dining_04   dining           5  repeated
# 2665        26  repeated   dining_03   dining           5  repeated
# 2666        27  repeated   dining_06   dining           5  repeated
# 2667        28  repeated   dining_07   dining           5  repeated
# 2668        29  repeated   dining_03   dining           6  repeated
# 2669        30  repeated   dining_06   dining           6  repeated
# 2670        31  repeated   dining_04   dining           6  repeated
# 2671        32  repeated   dining_07   dining           6  repeated
# 2672        33   control  waiting_00  waiting           1      post
# 2673        34   control  waiting_02  waiting           1      post
# 2674        35  repeated   dining_04   dining           7      post
# 2675        36  repeated   dining_03   dining           7      post
# 2676        37  repeated   dining_06   dining           7      post
# 2677        38   control  waiting_05  waiting           1      post
# 2678        39  repeated   dining_07   dining           7      post
# 2679        40   control  waiting_01  waiting           1      post
#
#      Generalization                        ...                          \
# 0            within                        ...
# 1            within                        ...
# 2            within                        ...
# 3            within                        ...
# 4            within                        ...
# 5            within                        ...
# 6            within                        ...
# 7            within                        ...
# 8            within                        ...
# 9            within                        ...
# 10           within                        ...
# 11           within                        ...
# 12           within                        ...
# 13           within                        ...
# 14           within                        ...
# 15           within                        ...
# 16           within                        ...
# 17           within                        ...
# 18           within                        ...
# 19           within                        ...
# 20           within                        ...
# 21           within                        ...
# 22           within                        ...
# 23           within                        ...
# 24           within                        ...
# 25           within                        ...
# 26           within                        ...
# 27           within                        ...
# 28           within                        ...
# 29           within                        ...
# ...             ...                        ...
# 2650        between                        ...
# 2651        between                        ...
# 2652        between                        ...
# 2653        between                        ...
# 2654        between                        ...
# 2655        between                        ...
# 2656        between                        ...
# 2657        between                        ...
# 2658        between                        ...
# 2659        between                        ...
# 2660        between                        ...
# 2661        between                        ...
# 2662        between                        ...
# 2663        between                        ...
# 2664        between                        ...
# 2665        between                        ...
# 2666        between                        ...
# 2667        between                        ...
# 2668        between                        ...
# 2669        between                        ...
# 2670        between                        ...
# 2671        between                        ...
# 2672        between                        ...
# 2673        between                        ...
# 2674        between                        ...
# 2675        between                        ...
# 2676        between                        ...
# 2677        between                        ...
# 2678        between                        ...
# 2679        between                        ...
#
#       numCurvesPerSketch  numCurvesPerStroke timedOut  \
# 0                      7            2.333333    False
# 1                     14            2.000000    False
# 2                     10            2.000000    False
# 3                     17            4.250000    False
# 4                     11            3.666667    False
# 5                     13            3.250000    False
# 6                      5            5.000000    False
# 7                     13            6.500000    False
# 8                     12            6.000000    False
# 9                      7            3.500000    False
# 10                    10            2.500000    False
# 11                    11            3.666667    False
# 12                    18            9.000000    False
# 13                     4            2.000000    False
# 14                    10            3.333333    False
# 15                    12            6.000000    False
# 16                     6            3.000000    False
# 17                    23           11.500000    False
# 18                     8            8.000000    False
# 19                    13            3.250000    False
# 20                     9            4.500000    False
# 21                    10            5.000000    False
# 22                     4            4.000000    False
# 23                     5            1.666667    False
# 24                    10            5.000000    False
# 25                     5            5.000000    False
# 26                     9            4.500000    False
# 27                     3            1.500000    False
# 28                     6            3.000000    False
# 29                     7            3.500000    False
# ...                  ...                 ...      ...
# 2650                  10            3.333333    False
# 2651                  18            3.600000    False
# 2652                  25            5.000000    False
# 2653                  35            3.181818    False
# 2654                  11            3.666667    False
# 2655                  29            5.800000    False
# 2656                  22            4.400000    False
# 2657                  18            6.000000    False
# 2658                   9            3.000000    False
# 2659                  16            4.000000    False
# 2660                  33            8.250000    False
# 2661                  21            5.250000    False
# 2662                  15            3.750000    False
# 2663                  12            2.400000    False
# 2664                  32           10.666667    False
# 2665                  10            2.500000    False
# 2666                  19            9.500000    False
# 2667                  23            5.750000    False
# 2668                   9            3.000000    False
# 2669                  42            6.000000    False
# 2670                  29            4.142857    False
# 2671                  16            5.333333    False
# 2672                  20            6.666667    False
# 2673                  13           13.000000    False
# 2674                  32            8.000000    False
# 2675                  14            2.800000    False
# 2676                  25            6.250000    False
# 2677                  18            9.000000    False
# 2678                  19            6.333333    False
# 2679                   9            1.800000    False
#
#                                                     png  \
# 0     iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 1     iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2     iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 3     iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 4     iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 5     iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 6     iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 7     iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 8     iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 9     iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 10    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 11    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 12    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 13    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 14    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 15    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 16    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 17    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 18    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 19    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 20    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 21    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 22    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 23    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 24    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 25    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 26    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 27    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 28    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 29    iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# ...                                                 ...
# 2650  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2651  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2652  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2653  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2654  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2655  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2656  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2657  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2658  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2659  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2660  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2661  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2662  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2663  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2664  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2665  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2666  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2667  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2668  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2669  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2670  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2671  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2672  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2673  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2674  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2675  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2676  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2677  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2678  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
# 2679  iVBORw0KGgoAAAANSUhEUgAAASwAAAEsCAYAAAB5fY51AA...
#
#                                               svgString  crazy  recog_id  \
# 0     [u'M87,105c0,-10.99517 24.80021,-15 32,-15c18....  False         0
# 1     [u'M76,71c11.17833,22.35667 13,51.12344 13,76'...  False        32
# 2     [u'M99,73c9.76816,0 21.5598,-9.5672 31,-13c12....  False        33
# 3     [u'M93,78c9.09243,9.09243 54.37526,-8.31237 67...  False         1
# 4     [u'M100,201c1.11783,1.11783 2,-29.63433 2,-36c...  False         2
# 5     [u'M87,122c27.20942,0 54.44369,-3 81,-3', u'M8...  False         3
# 6     [u'M89,153c0,-29.24917 -0.39833,-63.92033 35,-...  False        34
# 7     [u'M112,174c0,2.78464 -2.4007,79.4007 -4,81c-1...  False        35
# 8     [u'M93,205c6.54424,0 2.21105,-20.08284 3,-26c4...  False         6
# 9     [u'M180,140c-13.06007,0 -68.96917,5.06166 -56,...  False         4
# 10    [u'M66,129c19.29659,0 26.89525,8.89525 38,20',...  False         5
# 11    [u'M142,217c9.66433,4.83217 -18.56716,-27.7114...  False         7
# 12    [u'M86,75c6.8537,20.56111 1.66223,73.02663 -2,...  False        10
# 13    [u'M170,141c-12.65612,-6.32806 -83.87608,-7.97...  False         8
# 14    [u'M74,116c4.83034,4.83034 45,38.31172 45,43',...  False         9
# 15    [u'M137,238c0,-16.41582 -17.85737,-32.85737 -2...  False        11
# 16    [u'M98,158c12.45246,0 27.43721,6.0804 42,4c13....  False        12
# 17    [u'M177,187c2.4267,0 2.34319,-4.59769 2,-7c-2....  False        14
# 18    [u'M132,252c0.45958,0.45958 -8.10843,-10.6265 ...  False        15
# 19    [u'M75,243c2.04568,0 1,-3.31079 1,-5c0,-16.239...  False        13
# 20    [u'M65,86c0,39.72838 -7,76.00384 -7,115c0,4.98...  False        18
# 21    [u'M115,252c0,-15.72508 -14.31481,-25.62963 -2...  False        19
# 22    [u'M167,154c-12.64769,-12.64769 -83.31305,-15....  False        16
# 23    [u'M74,135c0,-1.41421 1.8233,-2.21554 3,-3c16....  False        17
# 24    [u'M69,100c6.62842,0 2.84812,23.66467 4,30c5.6...  False        22
# 25    [u'M183,149c-2.26612,-3.39918 -70.91618,-11.76...  False        20
# 26    [u'M121,238c-5.79572,-11.59143 -17.23379,-31.2...  False        23
# 27    [u'M84,131c7.53627,11.30441 23.97423,13.29897 ...  False        21
# 28    [u'M66,79c0,29.4654 -6.70447,106.1821 0,133c1....  False        26
# 29    [u'M139,245c-17.83476,0 -22.0481,-30.62025 -27...  False        27
# ...                                                 ...    ...       ...
# 2650  [u'M218,38c-10.33333,0 -20.66667,0 -31,0c-25,0...  False         0
# 2651  [u'M193,36c-24,0 -48,0 -72,0c-14.66667,0 -29.3...  False         2
# 2652  [u'M73,54c4.20138,0 8.05516,1.68505 12,3c0.201...  False         6
# 2653  [u'M86,56c6.33781,0 20.44024,2.77988 26,0c3.04...  False         7
# 2654  [u'M210,36c-44.78219,0 -86.97653,2.76201 -130,...  False         4
# 2655  [u'M220,55c-13.04373,0 -109.49831,-5.50169 -11...  False         5
# 2656  [u'M64,79c4.68854,0 14.75601,2.12199 19,0c4.49...  False        11
# 2657  [u'M227,37c-40.66667,0 -81.33333,0 -122,0c-19....  False         9
# 2658  [u'M205,57c-40.15524,0 -79.08724,3.92979 -119,...  False         8
# 2659  [u'M225,47c-18.36324,0 -36.60935,2 -55,2c-10,0...  False        10
# 22    ['waiting_04', 'waiting_00', 'waiting_01']
# 23    ['waiting_07', 'waiting_00', 'waiting_01']
# 24    ['waiting_07', 'waiting_04', 'waiting_01']
# 25    ['waiting_04', 'waiting_00', 'waiting_01']
# 26    ['waiting_07', 'waiting_04', 'waiting_00']
# 27    ['waiting_07', 'waiting_00', 'waiting_01']
# 28    ['waiting_07', 'waiting_04', 'waiting_01']
# 29    ['waiting_07', 'waiting_04', 'waiting_00']
# ...                                          ...
# 2650     ['dining_04', 'dining_06', 'dining_07']
# 2651     ['dining_03', 'dining_04', 'dining_07']
# 2652     ['dining_03', 'dining_04', 'dining_07']
# 2653     ['dining_03', 'dining_04', 'dining_06']
# 2654     ['dining_04', 'dining_06', 'dining_07']
# 2655     ['dining_03', 'dining_06', 'dining_07']
# 2656     ['dining_03', 'dining_04', 'dining_06']
# 2657     ['dining_03', 'dining_06', 'dining_07']
# 2658     ['dining_04', 'dining_06', 'dining_07']
# 2659     ['dining_03', 'dining_04', 'dining_07']
# 2660     ['dining_03', 'dining_06', 'dining_07']
# 2661     ['dining_03', 'dining_04', 'dining_07']
# 2662     ['dining_03', 'dining_04', 'dining_06']
# 2663     ['dining_04', 'dining_06', 'dining_07']
# 2664     ['dining_03', 'dining_06', 'dining_07']
# 2665     ['dining_04', 'dining_06', 'dining_07']
# 2666     ['dining_03', 'dining_04', 'dining_07']
# 2667     ['dining_03', 'dining_04', 'dining_06']
# 2668     ['dining_04', 'dining_06', 'dining_07']
# 2669     ['dining_03', 'dining_04', 'dining_07']
# 2670     ['dining_03', 'dining_06', 'dining_07']
# 2671     ['dining_03', 'dining_04', 'dining_06']
# 2672  ['waiting_01', 'waiting_05', 'waiting_02']
# 2673  ['waiting_01', 'waiting_00', 'waiting_05']
# 2674     ['dining_03', 'dining_06', 'dining_07']
# 2675     ['dining_04', 'dining_06', 'dining_07']
# 2676     ['dining_03', 'dining_04', 'dining_07']
# 2677  ['waiting_01', 'waiting_00', 'waiting_02']
# 2678     ['dining_03', 'dining_04', 'dining_06']
# 2679  ['waiting_00', 'waiting_05', 'waiting_02']
#
#                                    distractors_shapenet
# 0     ['2b5953c986dd08f2f91663a74ccd2338', '1d164136...
# 1     ['2eaab78d6e4c4f2d7b0c85d2effc7e09', '23b0da45...
# 2     ['2448d9aeda5bb9b0f4b6538438a0b930', '23b0da45...
# 3     ['309674bdec2d24d7597976c675750537', '1d164136...
# 4     ['309674bdec2d24d7597976c675750537', '2b5953c9...
# 5     ['309674bdec2d24d7597976c675750537', '2b5953c9...
# 6     ['2448d9aeda5bb9b0f4b6538438a0b930', '2eaab78d...
# 7     ['2448d9aeda5bb9b0f4b6538438a0b930', '2eaab78d...
# 8     ['309674bdec2d24d7597976c675750537', '2b5953c9...
# 9     ['2b5953c986dd08f2f91663a74ccd2338', '1d164136...
# 10    ['309674bdec2d24d7597976c675750537', '1d164136...
# 11    ['309674bdec2d24d7597976c675750537', '2b5953c9...
# 12    ['309674bdec2d24d7597976c675750537', '2b5953c9...
# 13    ['2b5953c986dd08f2f91663a74ccd2338', '1d164136...
# 2677  ['1da9942b2ab7082b2ba1fdc12ecb5c9e', '1d164136...
# 2678  ['3466b6ecd040e252c215f685ba622927', '38f87e02...
# 2679  ['1d1641362ad5a34ac3bd24f986301745', '2e291f35...
#
# [2680 rows x 25 columns]

# %% [markdown]
# ### load sketch features + metadata

# %%
reload(h)
cropping = 'no_crop'
base_path = '../../../data/features/'
path_to_feats = base_path + '{}/FEATURES_FC6_sketch.npy'.format(cropping)
path_to_meta = base_path + '{}/METADATA_sketch.csv'.format(cropping)

F = np.load(path_to_feats)
cors = np.corrcoef(F)
triu_inds = np.triu_indices(cors.shape[0], k = 1)
assert np.round(np.mean(cors[triu_inds]),2) != 1, 'F has redundant rows'

M = h.clean_up_metadata(pd.read_csv(path_to_meta))
assert F.shape[0]==M.shape[0], 'F and M are different sizes'

# %% [markdown]
# ## core analyses

# %% [markdown]
# ### 1. within-interaction

# %% [markdown]
# ##### accuracy

# %%
# what's the mean accuracy?
total = 0
for outcome in D['outcome']:
    total = total + outcome 
meanAccuracy = total / len(D['outcome'])
print ("accuracy: {}".format(meanAccuracy))
# Out:
# accuracy: 0.858582089552

# %%
# plot mean accuracy across repetitions 
reload(h)
h.plot_accuracy_reps(D)

# %% [markdown]
# ##### efficiency (based on cost and accuracy)

# %%
reload(h) ## write out bis dataframe 
drawDuration_accuracy_bis, numStrokes_accuracy_bis = h.save_bis_scores(D)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# ##### sketch similarity convergence

# %%
# ### create matrix for similarity between adjacent repetitions averaged within target and within game
reload(h)
arr_of_cormats = h.make_adjacency_matrix(M, F, 'gameID')

# %%
check = D[(D['category'] == 'waiting') & (D['condition'] == 'repeated') & (D['repetition'] == 0)]
check.head(1500)
# Out:
#       Unnamed: 0                                     gameID  trialNum  \
# 0              0  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         1
# 3              3  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         4
# 4              4  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         5
# 5              5  7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb         6
# 40            40  3558-8fa206a2-9b8c-4d67-a4ab-0832dc0d0f25         1
# 41            41  3558-8fa206a2-9b8c-4d67-a4ab-0832dc0d0f25         2
# 42            42  3558-8fa206a2-9b8c-4d67-a4ab-0832dc0d0f25         3
# 44            44  3558-8fa206a2-9b8c-4d67-a4ab-0832dc0d0f25         5
# 81            81  6964-d6de9966-f3dd-45df-8d24-d5bfd5d46eb8         2
# 83            83  6964-d6de9966-f3dd-45df-8d24-d5bfd5d46eb8         4
# 85            85  6964-d6de9966-f3dd-45df-8d24-d5bfd5d46eb8         6
# 86            86  6964-d6de9966-f3dd-45df-8d24-d5bfd5d46eb8         7
# 120          120  4853-a05bfdd7-095c-4b93-bdde-2b99fd29c7a2         1
# 121          121  4853-a05bfdd7-095c-4b93-bdde-2b99fd29c7a2         2
# 123          123  4853-a05bfdd7-095c-4b93-bdde-2b99fd29c7a2         4
# 127          127  4853-a05bfdd7-095c-4b93-bdde-2b99fd29c7a2         8
# 242          282  1820-86afdf51-4b4c-43a9-a9e1-e6e20618de1b         3
# 243          283  1820-86afdf51-4b4c-43a9-a9e1-e6e20618de1b         4
# 244          284  1820-86afdf51-4b4c-43a9-a9e1-e6e20618de1b         5
# 245          285  1820-86afdf51-4b4c-43a9-a9e1-e6e20618de1b         6
# 320          360  9075-d6c9b0a6-bfb2-4148-ae19-d0da518aef97         1
# 3     repeated  waiting_04  waiting           0   pre         within
# 4     repeated  waiting_00  waiting           0   pre         within
# 5     repeated  waiting_01  waiting           0   pre         within
# 40    repeated  waiting_07  waiting           0   pre         within
# 41    repeated  waiting_03  waiting           0   pre         within
# 42    repeated  waiting_00  waiting           0   pre         within
# 44    repeated  waiting_05  waiting           0   pre         within
# 81    repeated  waiting_06  waiting           0   pre         within
# 83    repeated  waiting_07  waiting           0   pre         within
# 85    repeated  waiting_03  waiting           0   pre         within
# 86    repeated  waiting_00  waiting           0   pre         within
# 120   repeated  waiting_00  waiting           0   pre         within
# 121   repeated  waiting_01  waiting           0   pre         within
# 123   repeated  waiting_02  waiting           0   pre         within
# 127   repeated  waiting_04  waiting           0   pre         within
# 242   repeated  waiting_02  waiting           0   pre         within
# 243   repeated  waiting_07  waiting           0   pre         within
# 244   repeated  waiting_00  waiting           0   pre         within
# 245   repeated  waiting_03  waiting           0   pre         within
# 320   repeated  waiting_05  waiting           0   pre         within
# 321   repeated  waiting_04  waiting           0   pre         within
# 322   repeated  waiting_02  waiting           0   pre         within
# 326   repeated  waiting_00  waiting           0   pre         within
# 360   repeated  waiting_01  waiting           0   pre         within
# 362   repeated  waiting_00  waiting           0   pre         within
# 364   repeated  waiting_05  waiting           0   pre         within
# 366   repeated  waiting_06  waiting           0   pre         within
# 920   repeated  waiting_03  waiting           0   pre         within
# 922   repeated  waiting_05  waiting           0   pre         within
# ...        ...         ...      ...         ...   ...            ...
# 1886  repeated  waiting_00  waiting           0   pre        between
# 1887  repeated  waiting_03  waiting           0   pre        between
# 1920  repeated  waiting_05  waiting           0   pre        between
# 1921  repeated  waiting_07  waiting           0   pre        between
# 1924  repeated  waiting_06  waiting           0   pre        between
# 1925  repeated  waiting_04  waiting           0   pre        between
# 1960  repeated  waiting_07  waiting           0   pre        between
# 1964  repeated  waiting_02  waiting           0   pre        between
# 1965  repeated  waiting_01  waiting           0   pre        between
# 1966  repeated  waiting_05  waiting           0   pre        between
# 2001  repeated  waiting_02  waiting           0   pre        between
# 2003  repeated  waiting_00  waiting           0   pre        between
# 2005  repeated  waiting_03  waiting           0   pre        between
# 2006  repeated  waiting_07  waiting           0   pre        between
# 2040  repeated  waiting_03  waiting           0   pre        between
# 2041  repeated  waiting_04  waiting           0   pre        between
# 2045  repeated  waiting_06  waiting           0   pre        between
# 2047  repeated  waiting_07  waiting           0   pre        between
# 2080  repeated  waiting_01  waiting           0   pre        between
# 2081  repeated  waiting_04  waiting           0   pre        between
# 2084  repeated  waiting_03  waiting           0   pre        between
# 2086  repeated  waiting_07  waiting           0   pre        between
# 2120  repeated  waiting_03  waiting           0   pre        between
# 2122  repeated  waiting_00  waiting           0   pre        between
# 2123  repeated  waiting_05  waiting           0   pre        between
# 2124  repeated  waiting_04  waiting           0   pre        between
# 2160  repeated  waiting_06  waiting           0   pre        between
# 2163  repeated  waiting_00  waiting           0   pre        between
# 2166  repeated  waiting_01  waiting           0   pre        between
# 2167  repeated  waiting_02  waiting           0   pre        between
#
#       drawDuration  outcome    response  numStrokes  meanPixelIntensity  \
# 0            5.415     True  waiting_07         3.0              0.0068
# 3            9.451    False  waiting_00         4.0              0.0203
# 4            8.538     True  waiting_00         3.0              0.0202
# 5            8.660     True  waiting_01         4.0              0.0165
# 40           9.105     True  waiting_07         6.0              0.0203
# 41           6.296    False  waiting_07         5.0              0.0155
# 42           6.504     True  waiting_00         2.0              0.0205
# 44          15.434     True  waiting_05         6.0              0.0276
# 81          11.921     True  waiting_06         6.0              0.0374
# 83           9.728     True  waiting_07         6.0              0.0362
# 85          13.618     True  waiting_03         7.0              0.0275
# 86           9.351     True  waiting_00         3.0              0.0341
# 120         10.735     True  waiting_00         3.0              0.0246
# 121         10.438     True  waiting_01         5.0              0.0326
# 123         20.335    False  waiting_04        13.0              0.0677
# 127         14.726     True  waiting_04        10.0              0.0478
# 242         22.932     True  waiting_02         7.0              0.0530
# 243          9.458     True  waiting_07         3.0              0.0246
# 244          9.971     True  waiting_00         3.0              0.0382
# 245          6.145     True  waiting_03         2.0              0.0236
# 320         13.822     True  waiting_05         8.0              0.0418
# 321         14.416    False  waiting_02         9.0              0.0579
# 322         17.591     True  waiting_02         9.0              0.0566
# 326         11.704     True  waiting_00         3.0              0.0413
# 360         18.920    False  waiting_00         3.0              0.0135
# 362         14.624     True  waiting_00         3.0              0.0317
# 364         12.515     True  waiting_05         1.0              0.0210
# 366          6.285     True  waiting_06         3.0              0.0157
# 920         25.236    False  waiting_05         7.0              0.0257
# 922          7.948     True  waiting_05         2.0              0.0157
# ...            ...      ...         ...         ...                 ...
# 1886        11.004    False  waiting_03         2.0              0.0188
# 1887         8.910     True  waiting_03         4.0              0.0384
# 1920        15.297    False  waiting_06         4.0              0.0209
# 1921        15.454     True  waiting_07         7.0              0.0307
# 1924        17.472    False  waiting_05         6.0              0.0264
# 1925        15.528    False  waiting_06         6.0              0.0135
# 1960         9.662     True  waiting_07         6.0              0.0275
# 1964        16.374     True  waiting_02         9.0              0.0419
# 1965         9.355     True  waiting_01         6.0              0.0375
# 1966        25.007     True  waiting_05         9.0              0.0774
# 2001        18.661    False  waiting_03         5.0              0.0282
# 2003        16.373     True  waiting_00         2.0              0.0432
# 2005         6.710     True  waiting_03         3.0              0.0073
# 2006         6.183     True  waiting_07         2.0              0.0118
# 2040         8.049     True  waiting_03         5.0              0.0280
# 2041         6.985     True  waiting_04         4.0              0.0220
# 2045         4.053    False  waiting_04         2.0              0.0311
# 2047         5.735     True  waiting_07         4.0              0.0159
# 2080         4.334     True  waiting_01         3.0              0.0280
# 2081         7.755    False  waiting_03         8.0              0.0394
# 2084         4.289     True  waiting_03         3.0              0.0243
# 2086         1.072     True  waiting_07         1.0              0.0174
# 2120        12.406     True  waiting_03         9.0              0.0427
# 2122        12.404     True  waiting_00         5.0              0.0515
# 2123        10.016     True  waiting_05         3.0              0.0363
# 2124        10.049     True  waiting_04         7.0              0.0347
# 2160        10.703     True  waiting_06         4.0              0.0194
# 2163        18.933     True  waiting_00         4.0              0.0488
# 2166        12.644     True  waiting_01         4.0              0.0424
# 2003  [u'M65,63c0,14.041 1.92422,30.26524 -2,44c-3.8...  False
# 2005  [u'M75,127c3.29514,0 2.3868,-23.32081 3,-27c3....  False
# 2006  [u'M68,102c8.07119,0 18.47087,-8.74126 26,-11c...  False
# 2040  [u'M30,124c0,-5.07026 36.91922,-22.62117 42,-1...  False
# 2041  [u'M27,143c0,8.27644 67.05061,19.33671 77,20c1...  False
# 2045  [u'M68,80c0,15.58921 2.47056,29.70574 6,45c1.4...  False
# 2047  [u'M34,47c32.5186,0 66.41398,-7.67243 99,-10c1...  False
# 2080  [u'M110,29c0,28.11678 14.22473,57.6742 23,84c6...  False
# 2081  [u'M93,121c-2.82781,0 -4.03866,8.07732 -5,10c-...  False
# 2084  [u'M18,104c1.99758,0 7.60275,6.40183 10,8c16.9...  False
# 2086  [u'M113,123c-16.23012,0 -46.50387,45.99226 -37...  False
# 2120  [u'M76,118c0,-20.84587 2.62311,-43.24622 11,-6...  False
# 2122  [u'M60,40c-1.97063,0 -1,22.84125 -1,26c0,27.56...  False
# 2123  [u'M55,239c13.96387,0 56.19466,54.87023 80,39c...  False
# 2124  [u'M62,105c0,8.87067 -9.16385,14.6723 -4,25c7....  False
# 2160  [u'M49,115c15.28882,0 21.67257,8.89675 30,20c3...  False
# 2163  [u'M90,45c9.98313,0 13.42377,35.06457 15,42c1....  False
# 2166  [u'M128,254c0,2.28944 -6.32001,1.48571 -7,1c-1...  False
# 2167  [u'M63,89c-5.77583,11.55165 1.88817,79.11829 0...  False
#
# [140 rows x 20 columns]

# %%
h.plot_within_interaction_similarity(arr_of_corrmats)

# %%
### permute across repetitions and create matrix for similarity between adjacent repetitions averaged within target and within game
M_pseudo = h.scramble_df_within_target_rep(M)
arr_of_corrmats_permuted = h.make_adjacency_matrix(M_pseudo, F, 'pseudo_gameID')

# %%
### just plotting one back similarities 
h.plot_within_interaction_similarity(arr_of_corrmats)

# %% [markdown]
# ### 2. between-interaction

# %% [markdown]
# ##### sketch similarity divergence

# %%
### calculates similarity of sketches between interactions within a repetition 
h.plot_between_interaction_similarity(M)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/ops.py:816: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-79befaf9f90a> in <module>()
#       1 ### calculates similarity of sketches between interactions within a repetition
# ----> 2 h.plot_between_interaction_similarity(M)
#
# /home/megsano/graphical_conventions/analysis/python/analysis_helpers.pyc in plot_between_interaction_similarity(M)
#     984         M_targ.sort_values(by=['repetition'])
#     985         for rep in range(8):
# --> 986             M_targ_rep = M_targ[M_targ['repetition'] == str(int(rep))]
#     987             inds_to_compare = M_targ_rep['feature_ind']
#     988             features_to_compare = F[inds_to_compare, :]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/ops.pyc in wrapper(self, other, axis)
#     877
#     878             with np.errstate(all='ignore'):
# --> 879                 res = na_op(values, other)
#     880             if is_scalar(res):
#     881                 raise TypeError('Could not compare {typ} type with Series'
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/ops.pyc in na_op(x, y)
#     816                     result = getattr(x, name)(y)
#     817                 if result is NotImplemented:
# --> 818                     raise TypeError("invalid type comparison")
#     819             except AttributeError:
#     820                 result = op(x, y)
#
# TypeError: invalid type comparison

# %% [markdown]
# ## supplementary analyses

# %%
# plotting 8 RDMs, one for each repetition 
fig, axs = plt.subplots(2, 4, sharex=True, sharey=True, figsize=(40,20))
for rep in range(8): 
    x_ind = rep % 4
    y_ind = 0 if rep < 4 else 1 
    M_rep = M[M['repetition'] == str(int(rep))]
    M_rep_sorted = M_rep.sort_values(by=['target'])
    sorted_feature_ind = list(M_rep_sorted['feature_ind'])
    get_and_plot_RDM(M_rep, F, sorted_feature_ind, axs, x_ind, y_ind, rep)
# Out:
# saving sketches from game: 7053-d1f771d6-a55b-4681-961f-5a9ebb43cbdb
# saving sketches from game: 3558-8fa206a2-9b8c-4d67-a4ab-0832dc0d0f25
# saving sketches from game: 6964-d6de9966-f3dd-45df-8d24-d5bfd5d46eb8
# saving sketches from game: 4853-a05bfdd7-095c-4b93-bdde-2b99fd29c7a2
# saving sketches from game: 5616-7114c020-0e81-482c-952b-b26fc66076a0
# saving sketches from game: 9817-6f2a66db-fc24-482d-aa20-1980ad6f524e
# saving sketches from game: 7527-5ab8c64c-3f95-4864-bb6a-f9cad4b0d34e
# saving sketches from game: 1820-86afdf51-4b4c-43a9-a9e1-e6e20618de1b
# saving sketches from game: 7438-c77fa69e-d41c-41a4-b530-fc2809c07323
# saving sketches from game: 9075-d6c9b0a6-bfb2-4148-ae19-d0da518aef97
# saving sketches from game: 7637-26870e81-faae-4521-a2e9-10424526a22c
# saving sketches from game: 4395-6cdb78e3-0c3f-4526-9670-8e4c1dcbc542
# saving sketches from game: 3480-03933bf3-5e7e-4ecd-b151-7ae57e6ae826
# saving sketches from game: 7360-1ccf92da-d46d-4315-8c81-6620388ee62f
# saving sketches from game: 8103-96ba70c4-9236-4e40-bc20-24712d13bf3d
# saving sketches from game: 4432-efb565d2-4b2c-4d55-af90-3a8c7d06477d
# saving sketches from game: 3546-9d7a95c2-b4c6-426d-935b-6da59496af1d
# saving sketches from game: 4516-5b316bf5-da1c-42cb-a9c1-0814d2b18f27
# saving sketches from game: 1781-59e66c90-3a35-4e43-aea6-6f8860c3a543
# saving sketches from game: 7421-9f538991-c10f-44fc-9dd1-e9b377065ad8
# saving sketches from game: 5408-c0bdf20b-7f65-49fb-aea3-0dd72e154ebd
# saving sketches from game: 5214-62825001-ac78-4b1f-b173-c837134e533b
# saving sketches from game: 0724-1a59371c-6fe6-4d6d-a987-db533e75a5e5
# saving sketches from game: 2040-7604415a-2963-4416-a78c-e2fdc7e670ac
# saving sketches from game: 8384-deeaec6b-d2a1-4f6e-ae6c-6140dfbb4071
# saving sketches from game: 6388-4e8fd744-2165-44fc-866a-5d68aff23732
# saving sketches from game: 1979-cf0efe08-9b6f-49a7-8200-43f0e7744dbc
# saving sketches from game: 2349-8db5cdc6-e266-4486-a9c2-b99b80593419
# saving sketches from game: 9614-d370a26e-7936-49e5-add7-05e6d31dda4a
# saving sketches from game: 6459-b31ded08-1443-4005-8cea-256cf02be3df
# saving sketches from game: 0286-a442ec93-ad78-42fa-b3e9-083da9a64c4d
# saving sketches from game: 4152-970406c3-17ba-435b-a56b-4f1f79f00119
# saving sketches from game: 4529-638b7428-2c20-4fb2-a388-1c7513f675d1
# saving sketches from game: 3522-5f73221e-1d4d-4e32-80ca-939e04b87bc3

# %% [markdown]
# ##### path-dependence

# %%
def get_corr_coefs(M,F):
    auto_corr_df = pd.DataFrame()
    for g in list(M['gameID'].unique()):
        for t in list(M[M['gameID'] == g]['target'].unique()):
            mini_df = M[(M['gameID'] == g) & (M['target'] == t)] 
            #mini_df = M[(M['gameID'] == '0050-769c4742-aefc-4bea-aeb2-7dc48b51fe82') & (M['target'] == 'dining_05')] 
            for base_rep in mini_df['repetition'].unique():
                base_ind = list(mini_df[mini_df['repetition'] == base_rep]['feature_ind'])[0]
                for other_rep in mini_df['repetition'].unique():
                    if base_rep < other_rep:# check if other_rep is bigger - only compare forward 
                        rep_dist = other_rep - base_rep
                        other_ind = list(mini_df[mini_df['repetition'] == other_rep]['feature_ind'])[0]
                        features_to_compare = F[[base_ind, other_ind], :]
                        corr_coef = np.corrcoef(features_to_compare)[1][0]
                        df_to_add = pd.DataFrame([[g, t, base_rep,  rep_dist, corr_coef]], columns=['gameID', 'target', 'base_rep', 'rep_dist', 'corr_coef'])
                        auto_corr_df = auto_corr_df.append(df_to_add)
    return auto_corr_df

auto_corr_df = get_corr_coefs(M, F)

# %%
# how does the similarity between sketches of adjacent repetitions change with increasing base repetition number? 
sns.regplot(
    data=auto_corr_df,
    x_estimator=np.mean,
    x='base_rep',
    y='corr_coef',
    logx=True)

# %%
# how does the similarity between sketches of adjacent repetitions change with increasing repetition distance? 
sns.regplot(
    data=auto_corr_df,
    x_estimator=np.mean,
    x='rep_dist',
    y='corr_coef')

# %%
new_df_ = pd.DataFrame()
for rep in auto_corr_df['base_rep'].unique():
    df_ = auto_corr_df[auto_corr_df['base_rep'] == rep]
    for dist in df_['rep_dist'].unique():
        _df = df_[df_['rep_dist'] == dist]
        mean = np.mean(np.array(_df['corr_coef']))
        df_to_add = pd.DataFrame([[rep, dist, mean]], columns=['base_rep', 'rep_dist', 'mean_corr_coef'])
        new_df_ = new_df_.append(df_to_add)

# %%
g = sns.FacetGrid(data=new_df_, col="rep_dist", height=3, aspect=1, col_wrap=4, margin_titles=True)
g = g.map(plt.scatter, "base_rep", "mean_corr_coef")
# g = sns.catplot(x="base_rep", y="mean_corr_coef",
#                 col="rep_dist", data=new_df_,col_wrap=2)

# %% [markdown]
# ##### classifier approach

# %%
#sklearn
from sklearn import decomposition, ensemble
from sklearn.model_selection import train_test_split
from sklearn.metrics  import accuracy_score
from sklearn.svm import LinearSVC
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.calibration import CalibratedClassifierCV

# %%
# make dataframe with just the first repetition 
M_0 = M[M['repetition'] == 0]
y = list(M_0['target'])
feature_inds = list(M_0['feature_ind'])
features = F[feature_inds, :]
x = pd.DataFrame(features)

X_train_0, X_test_0, y_train_0, y_test_0 = train_test_split(x, y, test_size = 0.2)

# make dataframe with just the last repetition 
M_7 = M[M['repetition'] == 7]
y = list(M_7['target'])
feature_inds = list(M_7['feature_ind'])
features = F[feature_inds, :]
x = pd.DataFrame(features)

X_train_7, X_test_7, y_train_7, y_test_7 = train_test_split(x, y, test_size = 0.2)

# %%
# makes training and testing sets for sketches from specific repetition 
def make_sets(M, rep):
    # make dataframe with just the last repetition 
    M_= M[M['repetition'] == rep]
    y = list(M_['target'])
    feature_inds = list(M_['feature_ind'])
    features = F[feature_inds, :]
    x = pd.DataFrame(features)
    return train_test_split(x, y, test_size = 0.2)

# %%
# make either training set or testing set (all sketches used for either one of them)
def get_x_and_y(M, rep):
    M_= M[M['repetition'] == rep]
    y = list(M_['target'])
    feature_inds = list(M_['feature_ind'])
    features = F[feature_inds, :]
    x = pd.DataFrame(features)
    return x, y

# %%
def classify_sketches(train_rep, test_rep):
    summary_df = pd.DataFrame()
    for i in range(1):
    
        # first train on the train_rep sketches
        X_train_, y_train_= get_x_and_y(M, train_rep)
        logreg = LogisticRegression(multi_class='multinomial', solver='newton-cg')
        #clf = CalibratedClassifierCV(log) 
        logreg.fit(X_train_, y_train_)
#         svc = LinearSVC(random_state=0)
#         clf = CalibratedClassifierCV(svc) 
#         clf.fit(X_train_, y_train_)

        # for each repetition, predict from features, record accuracy and class probability    
        for rep in test_rep:
            X_test, y_test = get_x_and_y(M, rep)
            y_pred = logreg.predict(X_test)
            acc = accuracy_score(y_test, y_pred)
            prob = logreg.predict_proba(X_test)
            prob_df_svc = pd.DataFrame(prob)
            prob_df_svc.columns=list(logreg.classes_)
            prob_df_svc['target'] = y_test
            prob_list = []
            prob_df_svc = prob_df_svc.reset_index(drop=True)
            for j, d in prob_df_svc.iterrows():
                target = d['target']
                class_prob = d[target]
                prob_list.append(class_prob)
            mean_prob = np.mean(prob_list)

            df_to_add = pd.DataFrame([[i, rep, acc, mean_prob]], columns=['iteration','test_rep', 'accuracy', 'class_prob'])
            summary_df = summary_df.append(df_to_add)

    return summary_df

# %%
summary_df0 = classify_sketches(0, [1,7])
summary_df7 = classify_sketches(7, [6,0])
summary_df0['train_rep'] = [0] * summary_df0.shape[0]
summary_df7['train_rep'] = [7] * summary_df7.shape[0]
summary_df_list = [summary_df0, summary_df7]
combined_df = pd.concat(summary_df_list, axis=0)
combined_df = combined_df.reset_index(drop=True)
distance_list = []
for i,d in combined_df.iterrows():
    distance_list.append(abs(d['test_rep']-d['train_rep']))
combined_df['distance'] = distance_list
combined_df = combined_df.reset_index(drop=True)

# %%
sns.set_context("paper")
plt.figure(figsize=(5,5))
sns.pointplot(
    data=combined_df,
    x='distance',
    y='accuracy',
    hue='train_rep',
    palette="Set1")

# %%
def get_x_and_y_permute(M, rep):
    M_= M[M['pseudo_repetition'] == rep]
    y = list(M_['target'])
    feature_inds = list(M_['feature_ind'])
    features = F[feature_inds, :]
    x = pd.DataFrame(features)
    return x, y

# %%
def classify_sketches_permute(train_rep, test_rep):
    summary_df = pd.DataFrame()
    
    # first train on the train_rep sketches
    X_train_, y_train_= get_x_and_y_permute(M, train_rep)
    logreg = LogisticRegression(multi_class='multinomial', solver='newton-cg')
    #clf = CalibratedClassifierCV(log) 
    logreg.fit(X_train_, y_train_)
#         svc = LinearSVC(random_state=0)
#         clf = CalibratedClassifierCV(svc) 
#         clf.fit(X_train_, y_train_)

    # for each repetition, predict from features, record accuracy and class probability    
    for rep in test_rep:
        X_test, y_test = get_x_and_y_permute(M, rep)
        y_pred = logreg.predict(X_test)
        acc = accuracy_score(y_test, y_pred) # temporarily just do accuracy 
#         prob = logreg.predict_proba(X_test)
#         prob_df_svc = pd.DataFrame(prob)
#         prob_df_svc.columns=list(logreg.classes_)
#         prob_df_svc['target'] = y_test
#         prob_list = []
#         prob_df_svc = prob_df_svc.reset_index(drop=True)
#         for j, d in prob_df_svc.iterrows():
#             target = d['target']
#             class_prob = d[target]
#             prob_list.append(class_prob)
        mean_prob = 1#np.mean(prob_list)

        df_to_add = pd.DataFrame([[i, rep, acc, mean_prob]], columns=['iteration','test_rep', 'accuracy', 'class_prob'])
        summary_df = summary_df.append(df_to_add)

    return summary_df

# %%
final_combined_df_permute = pd.DataFrame()
random_seed = 4000000000
for i in range(1000):
    if i % 100 == 0:
        print (str(i) + "th iteration")
    pseudo_rep_list = []
    for g in list(M['gameID'].unique()):
        for t in list(M[M['gameID'] == g]['target'].unique()):
            mini_df = M[(M['gameID'] == g) & (M['target'] == t)] 
            rep_list = np.array(mini_df['repetition'])
            # pass in different random seed for each one 
            np.random.seed(random_seed)
            shuffled_rep_list = np.random.permutation(rep_list)
            pseudo_rep_list = pseudo_rep_list + list(shuffled_rep_list)
            random_seed = random_seed - 1
    M['pseudo_repetition'] = pseudo_rep_list
    summary_df0 = classify_sketches_permute(0, [1,7])
    summary_df7 = classify_sketches_permute(7, [6,0])
    summary_df0['train_rep'] = [0] * summary_df0.shape[0]
    summary_df7['train_rep'] = [7] * summary_df7.shape[0]
    summary_df_list = [summary_df0, summary_df7]
    combined_df_permute = pd.concat(summary_df_list, axis=0)
    combined_df_permute = combined_df_permute.reset_index(drop=True)
    distance_list = []
    for j,d in combined_df_permute.iterrows():
        distance_list.append(abs(d['test_rep']-d['train_rep']))
    combined_df_permute['distance'] = distance_list
    combined_df_permute = combined_df_permute.reset_index(drop=True)
    final_combined_df_permute = final_combined_df_permute.append(combined_df_permute)#add(combined_df_permute, fill_value=0)
result = final_combined_df_permute / 1000

# %%
sns.set_context("paper")
plt.figure(figsize=(5,5))
g = sns.pointplot(
    data=final_combined_df_permute,
    x='distance',
    y='accuracy',
    hue='train_rep',
    palette="Set1")
g.set(ylim=(0.5, 0.6))

# %%
sns.set_context("paper")
plt.figure(figsize=(5,5))
sns.pointplot(
    data=final_combined_df_permute,
    x='distance',
    y='accuracy',
    hue='train_rep',
    palette="Set1")

# %% [markdown]
# ##### bootstrap

# %%
# make either training set or testing set (all sketches used for either one of them)
from sklearn.metrics import log_loss
def get_x_and_y(M, rep):
    M_= M[M['repetition'] == rep]
    y = list(M_['target'])
    feature_inds = list(M_['feature_ind'])
    features = F[feature_inds, :]
    x = pd.DataFrame(features)
    return x, y

def get_training_set_error(train_rep):
    X_train, y_train = get_x_and_y(M, train_rep)
    targets = pd.Series(y_train).unique()
    logreg = LogisticRegression(multi_class='multinomial', solver='newton-cg')
    logreg.fit(X_train, y_train)
    #y_pred = logreg.predict(X_test)
    y_pred = logreg.predict_proba(X_train)
    # train classifier on these sample sketches from repetition (train) and test on sketches from game g repetition (test)
    classification_loss = log_loss(y_train, y_pred, labels=targets)
    return classification_loss

# %%
games = list(M['gameID'].unique())
#targets = list(M['target'].unique())
number_of_games = len(games)

bootstrap_samples = []
for i in range(1000):
    sample = np.random.choice(number_of_games, number_of_games)
    bootstrap_samples.append(sample)
    
def get_error(train_rep, test_rep):
    
    #grand_total_classification_loss = 0
    err_df = pd.DataFrame()
    for g in games:
        print("computing average classification loss for game " + g + " with train rep: " + str(train_rep) + " and test rep: " + str(test_rep))

        samples_without_g = [sample for sample in bootstrap_samples if games.index(g) not in sample] 
        total_classification_loss = 0
        training_set_error = get_training_set_error(train_rep)
        sample_index=0
        for sample in samples_without_g:
            games_ = pd.Series(games)
            sample_games = games_[sample] # sample is just a list of indices, so get actual games 
            sample_games = list(sample_games)
            M_train = M[M['gameID'].isin(sample_games)]
            X_train, y_train = get_x_and_y(M_train, train_rep)
            targets = pd.Series(y_train).unique()
            M_test = M[M['gameID'] == g]
            X_test, y_test = get_x_and_y(M_test, test_rep)
            logreg = LogisticRegression(multi_class='multinomial', solver='newton-cg')
            logreg.fit(X_train, y_train)
            #y_pred = logreg.predict(X_test)
            y_pred = logreg.predict_proba(X_test)
            # train classifier on these sample sketches from repetition (train) and test on sketches from game g repetition (test)
            classification_loss = log_loss(y_test, y_pred, labels=targets)
            total_classification_loss = total_classification_loss + classification_loss
            sample_index=sample_index+1
        average_classification_loss = total_classification_loss / len(samples_without_g)
        error = 0.632 * average_classification_loss + 0.368 * training_set_error
        df_to_add = pd.DataFrame([[error, g, sample_index, train_rep, test_rep]], columns=['error', 'gameID', 'sample_index', 'train_rep', 'test_rep'])
        err_df = err_df.append(df_to_add)
        #grand_total_classification_loss = grand_total_classification_loss + average_classification_loss
    #grand_average_classification_loss = grand_total_classification_loss / len(games)

    #error_632 = 0.632 * grand_average_classification_loss + 0.368 * training_set_error 
    return err_df

# df_0_1 = get_error(0,1)
# df_0_1.to_csv("df_0_1.csv")
df_0_7 = get_error(0,7)
df_0_7.to_csv("df_0_7.csv")
df_7_6 = get_error(7,6)
df_7_6.to_csv("df_7_6.csv")
df_7_0 = get_error(7,0)
df_7_0.to_csv("df_7_0.csv")

# %%
df_0_1 = pd.read_csv("df_0_1.csv")
all_err_df = pd.concat([df_0_1, df_0_7, df_7_6, df_7_0])
all_err_df.to_csv("all_err_df.csv")

# %%
# convert to and add distance 
all_err_df = pd.read_csv("all_err_df.csv")
distance_list = []
for j,d in all_err_df.iterrows():
    distance_list.append(abs(d['test_rep']-d['train_rep']))
all_err_df['distance'] = distance_list

sns.set_context("paper")
plt.figure(figsize=(5,5))
sns.pointplot(
    data=all_err_df,
    x='distance',
    y='error',
    hue='train_rep',
    palette="Set1")
